# %% [markdown]
# # **Preparació de les dades**
#
# De CSV amb dades hi ha:
#
# 1- **ABIDEII_Composite_Phenotypic.csv** - conté les dades fenotípiques que han guardat els diferents laboratoris, una de les dades de cada subjecte és l'ID del laboratori que ha fet l'escanner (arxiu descarregat de ABIDEII)
#
# 2- **qc.csv** - puntuacions control de qualitat de mri_synthseg, calculat directament sobre arxiu nifti, la columna subject té el nom de l'arxiu comprobat (i l'ID del subjecte com a part del nom de l'arxiu)
#
# 3- **vol.csv**- aquí hi ha els volumns retornats de mri_synthseg, calculat directament sobre arxiu nifti, la columna subject té el nom de l'arxiu comprobat (i l'ID del subjecte com a part del nom de l'arxiu)
#
# Aquí es generen dos csv nous amb les totes les dades que hi ha a **qc.csv** juntament amb informació extreta de **ABIDEII_Composite_Phenotypic.csv** i l'altre amb les dades de **vol.csv** més la informaciò de **ABIDEII_Composite_Phenotypic.csv**, de l'arxiu de dades fenotípiques se n'extreuen els següents paràmetres:
#
# - nom del laboratori (SITE_ID)
# - ID del subjecte (SUB_ID)
# - edat(AGE_AT_SCAN )
# - sexe (SEX)
# - si és TEA o control(DX_GROUP)
# - Resultat Global IQ
#
# Es generen dos arxius CSV nous:
#
# - *Dataset_to_Check_vol.csv*
# - *Dataset_to_Check_qc.csv*

# %% [markdown]
# ## **PAS1: importar llibreries**

# %%
# numpy i Pandas per manipular dades
import numpy as np
import pandas as pd
# per visualitzar dades
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import os
# enllaça a drive
from google.colab import drive

# %% [markdown]
# ## **PAS2: enllaçar amb drive**

# %%
#paths relatius a l'arxiu ipynb
import glob
# recuperar ruta de l0scritp
script_name = '1_Dataset_Treball.ipynb'
drive.mount(os.getcwd() + '/drive')
script_path = glob.glob(os.getcwd() + '/**/' + script_name, recursive = True)
print(script_path)
head_tail = os.path.split(script_path[0])
# guardem carpeta de treball
work_path = head_tail[0];
# Out:
# Mounted at /content/drive
# ['/content/drive/MyDrive/TFM/Finals/1_Dataset_Treball.ipynb']

# %% [markdown]
# ## **PAS3: llegir arxius**

# %%
# PATHS
#dades fenotípiques
fenotip_path = work_path + '/CSV/ABIDEII_Composite_Phenotypic.csv'
# resultats control de qualitat mri_synthseg sobre imatges normalitzades a NMI
qc_path = work_path + '/CSV/qc.csv'
# volums extrets de mri_synthseg sobre imatges normalitzades a NMI
v_path = work_path + '/CSV/Vol.csv'
# path de l'arxiu combinat
merged_qc_path = work_path + '/CSV/Dataset_to_Check_qc.csv'
merged_v_path = work_path + '/CSV/Dataset_to_Check_vol.csv'
# LLEGIR DADES
#dades fenotípiques
fenotip = pd.read_csv(fenotip_path, encoding='latin-1')
#dades qc
qc = pd.read_csv(qc_path)
#volums
v = pd.read_csv(v_path)

# %%
# contingut arxiu dades fenotípiques
fenotip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1114 entries, 0 to 1113
# Columns: 348 entries, SITE_ID to ADI_R_D_INTERVIEWER_JUDGMENT
# dtypes: float64(337), int64(3), object(8)
# memory usage: 3.0+ MB

# %%
# contingut arxiu resultats qc
qc.head()
# Out:
#         subject  general white matter  general grey matter  general csf  \
# 0  28675_1_anat                0.8369               0.7688       0.8097
# 1    28676_anat                0.8744               0.7679       0.8697
# 2    28677_anat                0.8742               0.7587       0.8179
# 3    28678_anat                0.8529               0.7679       0.8868
# 4  28679_1_anat                0.8640               0.7848       0.7588
#
#    cerebellum  brainstem  thalamus  putamen+pallidum  hippocampus+amygdala
# 0      0.9141     0.8966    0.8578            0.9152                0.8835
# 1      0.8838     0.8872    0.8997            0.9341                0.8796
# 2      0.8990     0.8537    0.8774            0.9198                0.8929
# 3      0.9063     0.8618    0.8790            0.9038                0.8573
# 4      0.8679     0.8660    0.8772            0.9112                0.8881

# %%
# contingut arxiu de volums
v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 34 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   subject                           370 non-null    object
#  1   total intracranial                370 non-null    float64
#  2   left cerebral white matter        370 non-null    float64
#  3   left cerebral cortex              370 non-null    float64
#  4   left lateral ventricle            370 non-null    float64
#  5   left inferior lateral ventricle   370 non-null    float64
#  6   left cerebellum white matter      370 non-null    float64
#  7   left cerebellum cortex            370 non-null    float64
#  8   left thalamus                     370 non-null    float64
#  9   left caudate                      370 non-null    float64
#  10  left putamen                      370 non-null    float64
#  11  left pallidum                     370 non-null    float64
#  12  3rd ventricle                     370 non-null    float64
#  13  4th ventricle                     370 non-null    float64
#  14  brain-stem                        370 non-null    float64
#  15  left hippocampus                  370 non-null    float64
#  16  left amygdala                     370 non-null    float64
#  17  csf                               370 non-null    float64
#  18  left accumbens area               370 non-null    float64
#  19  left ventral DC                   370 non-null    float64
#  20  right cerebral white matter       370 non-null    float64
#  21  right cerebral cortex             370 non-null    float64
#  22  right lateral ventricle           370 non-null    float64
#  23  right inferior lateral ventricle  370 non-null    float64
#  24  right cerebellum white matter     370 non-null    float64
#  25  right cerebellum cortex           370 non-null    float64
#  26  right thalamus                    370 non-null    float64
#  27  right caudate                     370 non-null    float64
#  28  right putamen                     370 non-null    float64
#  29  right pallidum                    370 non-null    float64
#  30  right hippocampus                 370 non-null    float64
#  31  right amygdala                    370 non-null    float64
#  32  right accumbens area              370 non-null    float64
#  33  right ventral DC                  370 non-null    float64
# dtypes: float64(33), object(1)
# memory usage: 98.4+ KB

# %% [markdown]
# El vincle està en el camp "**subject**" de tipus object de l'arxiu de resultats de control de qualitat amb el camp "**SUB_ID**" de l'arxiu amb les dades fenotípiques

# %%
fenotip.head()
# Out:
#          SITE_ID  SUB_ID NDAR_GUID  DX_GROUP  PDD_DSM_IV_TR  ASD_DSM_5  \
# 0  ABIDEII-BNI_1   29006       NaN         1            NaN        NaN
# 1  ABIDEII-BNI_1   29007       NaN         1            NaN        NaN
# 2  ABIDEII-BNI_1   29008       NaN         1            NaN        NaN
# 3  ABIDEII-BNI_1   29009       NaN         1            NaN        NaN
# 4  ABIDEII-BNI_1   29010       NaN         1            NaN        NaN
#
#    AGE_AT_SCAN   SEX  HANDEDNESS_CATEGORY  HANDEDNESS_SCORES  ...  \
# 0          48.0    1                  1.0                NaN  ...
# 1          41.0    1                  1.0                NaN  ...
# 2          59.0    1                  1.0                NaN  ...
# 3          57.0    1                  1.0                NaN  ...
# 4          45.0    1                  1.0                NaN  ...
#
#    ADI_R_C3_TOTAL  ADI_R_C4_REPETITIVE_USE_OBJECTS  ADI_R_C4_HIGHER  \
# 0             NaN                              NaN              NaN
# 1             NaN                              NaN              NaN
# 2             NaN                              NaN              NaN
# 3             NaN                              NaN              NaN
# 4             NaN                              NaN              NaN
#
#   ADI_R_C4_UNUSUAL_SENSORY_INTERESTS ADI_R_C4_TOTAL  \
# 0                                NaN            NaN
# 1                                NaN            NaN
# 2                                NaN            NaN
# 3                                NaN            NaN
# 4                                NaN            NaN
#
#   ADI_R_D_AGE_PARENT_NOTICED  ADI_R_D_AGE_FIRST_SINGLE_WORDS  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    ADI_R_D_AGE_FIRST_PHRASES  ADI_R_D_AGE_WHEN_ABNORMALITY  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#    ADI_R_D_INTERVIEWER_JUDGMENT
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 348 columns]

# %% [markdown]
# Eliminar files que no continguin SUB_ID del dataset carregat amb l'arxiu de dades fenotípiques

# %%
# eliminar files que continguin el camp SUB_ID a NaN
fenotip.dropna(axis=0, subset='SUB_ID',  how='all', inplace = True)
fenotip.head()
# Out:
#          SITE_ID  SUB_ID NDAR_GUID  DX_GROUP  PDD_DSM_IV_TR  ASD_DSM_5  \
# 0  ABIDEII-BNI_1   29006       NaN         1            NaN        NaN
# 1  ABIDEII-BNI_1   29007       NaN         1            NaN        NaN
# 2  ABIDEII-BNI_1   29008       NaN         1            NaN        NaN
# 3  ABIDEII-BNI_1   29009       NaN         1            NaN        NaN
# 4  ABIDEII-BNI_1   29010       NaN         1            NaN        NaN
#
#    AGE_AT_SCAN   SEX  HANDEDNESS_CATEGORY  HANDEDNESS_SCORES  ...  \
# 0          48.0    1                  1.0                NaN  ...
# 1          41.0    1                  1.0                NaN  ...
# 2          59.0    1                  1.0                NaN  ...
# 3          57.0    1                  1.0                NaN  ...
# 4          45.0    1                  1.0                NaN  ...
#
#    ADI_R_C3_TOTAL  ADI_R_C4_REPETITIVE_USE_OBJECTS  ADI_R_C4_HIGHER  \
# 0             NaN                              NaN              NaN
# 1             NaN                              NaN              NaN
# 2             NaN                              NaN              NaN
# 3             NaN                              NaN              NaN
# 4             NaN                              NaN              NaN
#
#   ADI_R_C4_UNUSUAL_SENSORY_INTERESTS ADI_R_C4_TOTAL  \
# 0                                NaN            NaN
# 1                                NaN            NaN
# 2                                NaN            NaN
# 3                                NaN            NaN
# 4                                NaN            NaN
#
#   ADI_R_D_AGE_PARENT_NOTICED  ADI_R_D_AGE_FIRST_SINGLE_WORDS  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    ADI_R_D_AGE_FIRST_PHRASES  ADI_R_D_AGE_WHEN_ABNORMALITY  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#    ADI_R_D_INTERVIEWER_JUDGMENT
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 348 columns]

# %%
# convertir SUB_ID a string
fenotip['SUB_ID'] = fenotip['SUB_ID'].astype(int)
fenotip['SUB_ID'] = fenotip['SUB_ID'].astype(str)
fenotip.head()
# Out:
#          SITE_ID SUB_ID NDAR_GUID  DX_GROUP  PDD_DSM_IV_TR  ASD_DSM_5  \
# 0  ABIDEII-BNI_1  29006       NaN         1            NaN        NaN
# 1  ABIDEII-BNI_1  29007       NaN         1            NaN        NaN
# 2  ABIDEII-BNI_1  29008       NaN         1            NaN        NaN
# 3  ABIDEII-BNI_1  29009       NaN         1            NaN        NaN
# 4  ABIDEII-BNI_1  29010       NaN         1            NaN        NaN
#
#    AGE_AT_SCAN   SEX  HANDEDNESS_CATEGORY  HANDEDNESS_SCORES  ...  \
# 0          48.0    1                  1.0                NaN  ...
# 1          41.0    1                  1.0                NaN  ...
# 2          59.0    1                  1.0                NaN  ...
# 3          57.0    1                  1.0                NaN  ...
# 4          45.0    1                  1.0                NaN  ...
#
#    ADI_R_C3_TOTAL  ADI_R_C4_REPETITIVE_USE_OBJECTS  ADI_R_C4_HIGHER  \
# 0             NaN                              NaN              NaN
# 1             NaN                              NaN              NaN
# 2             NaN                              NaN              NaN
# 3             NaN                              NaN              NaN
# 4             NaN                              NaN              NaN
#
#   ADI_R_C4_UNUSUAL_SENSORY_INTERESTS ADI_R_C4_TOTAL  \
# 0                                NaN            NaN
# 1                                NaN            NaN
# 2                                NaN            NaN
# 3                                NaN            NaN
# 4                                NaN            NaN
#
#   ADI_R_D_AGE_PARENT_NOTICED  ADI_R_D_AGE_FIRST_SINGLE_WORDS  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    ADI_R_D_AGE_FIRST_PHRASES  ADI_R_D_AGE_WHEN_ABNORMALITY  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#    ADI_R_D_INTERVIEWER_JUDGMENT
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 348 columns]

# %%
qc.head()
# Out:
#         subject  general white matter  general grey matter  general csf  \
# 0  28675_1_anat                0.8369               0.7688       0.8097
# 1    28676_anat                0.8744               0.7679       0.8697
# 2    28677_anat                0.8742               0.7587       0.8179
# 3    28678_anat                0.8529               0.7679       0.8868
# 4  28679_1_anat                0.8640               0.7848       0.7588
#
#    cerebellum  brainstem  thalamus  putamen+pallidum  hippocampus+amygdala
# 0      0.9141     0.8966    0.8578            0.9152                0.8835
# 1      0.8838     0.8872    0.8997            0.9341                0.8796
# 2      0.8990     0.8537    0.8774            0.9198                0.8929
# 3      0.9063     0.8618    0.8790            0.9038                0.8573
# 4      0.8679     0.8660    0.8772            0.9112                0.8881

# %% [markdown]
# ## **PAS4: Vincular dades**

# %% [markdown]
# Afegeixo la informació d'IQ, per calcular-ho han fet servir diferents tipus de test, afegeixo els camps FIQ, PIQ i PIQ_TEST_TYPE, perquè hi ha algun laboratori que no ha calculat el global (FIQ), aquells que han fet servir el test **Raven** només han omplert el camp PIQ (Performance IQ)

# %%
#primer em quedo amb les columnes fenotípiques que m'interessen
# SITE_ID
# SUB_ID
# DX_GROUP
# AGE_AT_SCAN
# SEX
f_data = fenotip[['SITE_ID','SUB_ID', 'DX_GROUP','AGE_AT_SCAN ','SEX','FIQ','PIQ', 'PIQ_TEST_TYPE']]
f_data.head()
# Out:
#          SITE_ID SUB_ID  DX_GROUP  AGE_AT_SCAN   SEX    FIQ  PIQ PIQ_TEST_TYPE
# 0  ABIDEII-BNI_1  29006         1          48.0    1  131.0  NaN           NaN
# 1  ABIDEII-BNI_1  29007         1          41.0    1  110.0  NaN           NaN
# 2  ABIDEII-BNI_1  29008         1          59.0    1  117.0  NaN           NaN
# 3  ABIDEII-BNI_1  29009         1          57.0    1  114.0  NaN           NaN
# 4  ABIDEII-BNI_1  29010         1          45.0    1  109.0  NaN           NaN

# %%
#generar dataframe combinat
# https://www.geeksforgeeks.org/python/join-pandas-dataframes-matching-by-substring/
f_data['join'] = 1
qc['join'] = 1
v ['join'] = 1

full_qc_df = f_data.merge(qc, on='join').drop('join', axis=1)
full_v_df = f_data.merge(v, on='join').drop('join', axis=1)

qc.drop('join', axis=1, inplace=True)
v.drop('join', axis=1, inplace=True)

# només ens quedem amb lesdades dels subjectes que hem processat
full_qc_df['match'] = full_qc_df.apply( lambda x: x.subject.find(str(x.SUB_ID)), axis=1).ge(0)
full_v_df['match'] = full_v_df.apply( lambda x: x.subject.find(str(x.SUB_ID)), axis=1).ge(0)
# Out:
# /tmp/ipython-input-128206011.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['join'] = 1

# %%
full_v_df.head()
# Out:
#          SITE_ID SUB_ID  DX_GROUP  AGE_AT_SCAN   SEX    FIQ  PIQ  \
# 0  ABIDEII-BNI_1  29006         1          48.0    1  131.0  NaN
# 1  ABIDEII-BNI_1  29006         1          48.0    1  131.0  NaN
# 2  ABIDEII-BNI_1  29006         1          48.0    1  131.0  NaN
# 3  ABIDEII-BNI_1  29006         1          48.0    1  131.0  NaN
# 4  ABIDEII-BNI_1  29006         1          48.0    1  131.0  NaN
#
#   PIQ_TEST_TYPE       subject  total intracranial  ...  \
# 0           NaN  28675_1_anat           1338241.2  ...
# 1           NaN    28676_anat           1781819.0  ...
# 2           NaN    28677_anat           1639514.2  ...
# 3           NaN    28678_anat           1397601.8  ...
# 4           NaN  28679_1_anat           1647357.8  ...
#
#    right cerebellum cortex  right thalamus  right caudate  right putamen  \
# 0                56115.630        6612.350       3995.760       4843.594
# 1                60841.600        9226.183       5315.918       6586.380
# 2                58436.637        8529.139       5048.086       6024.036
# 3                53459.700        6431.748       3580.828       4647.038
# 4                58825.110        8389.996       4930.436       5571.388
#
#    right pallidum  right hippocampus  right amygdala  right accumbens area  \
# 0        1441.631           4401.238        1529.647               707.751
# 1        1926.226           4452.581        2109.016               757.012
# 2        1692.341           4832.502        1901.521               741.057
# 3        1423.337           3902.226        1608.444               605.127
# 4        1961.566           5251.076        2035.279               875.499
#
#    right ventral DC  match
# 0          3852.000  False
# 1          5055.705  False
# 2          4530.029  False
# 3          3422.313  False
# 4          4998.054  False
#
# [5 rows x 43 columns]

# %%
# Resultats Control de qualitat - eliminar files que no han estat vinculades
matched_qc_df  = full_qc_df[full_qc_df['match'] == True]
matched_qc_df.shape
# Out:
# (370, 18)

# %% [markdown]
# Imputar valors de IQ faltants: en aquells que han fet un test de **raven**, que no tenen FIQ (IQ Global) assino el valor del performance (PIQ) a FIQ, en els altres casos ho deixo en blanc (en principi no faré servir l'IQ)

# %%
rule = (matched_qc_df['FIQ'].isna()) & (matched_qc_df['PIQ_TEST_TYPE'] == 'Raven')
matched_qc_df.loc[rule, 'FIQ'] = matched_qc_df.loc[rule,'PIQ']

# %%
# eliminar columna matched i els camps d'IQ que ja no fan falta
matched_qc_df.drop(['match','PIQ_TEST_TYPE','PIQ'], axis=1, inplace=True)
matched_qc_df.reset_index(drop=True, inplace=True)
matched_qc_df.head()
# Out:
#          SITE_ID SUB_ID  DX_GROUP  AGE_AT_SCAN   SEX    FIQ     subject  \
# 0  ABIDEII-BNI_1  29006         1          48.0    1  131.0  29006_anat
# 1  ABIDEII-BNI_1  29007         1          41.0    1  110.0  29007_anat
# 2  ABIDEII-BNI_1  29008         1          59.0    1  117.0  29008_anat
# 3  ABIDEII-BNI_1  29009         1          57.0    1  114.0  29009_anat
# 4  ABIDEII-BNI_1  29010         1          45.0    1  109.0  29010_anat
#
#    general white matter  general grey matter  general csf  cerebellum  \
# 0                0.8624               0.7574       0.8766      0.8818
# 1                0.8670               0.7595       0.7779      0.8834
# 2                0.8682               0.7831       0.8821      0.8922
# 3                0.8610               0.7644       0.8528      0.8810
# 4                0.8686               0.7892       0.8626      0.9019
#
#    brainstem  thalamus  putamen+pallidum  hippocampus+amygdala
# 0     0.8568    0.8979            0.9099                0.8691
# 1     0.8639    0.8667            0.9122                0.8650
# 2     0.8938    0.8925            0.8989                0.8896
# 3     0.8733    0.8771            0.9054                0.8839
# 4     0.9043    0.8849            0.8974                0.9007

# %%
# VOlums extrets - eliminar files que no han estat vinculades
matched_v_df  = full_v_df[full_v_df['match'] == True]
matched_v_df.shape
# Out:
# (370, 43)

# %%
rule = (matched_v_df['FIQ'].isna()) & (matched_v_df['PIQ_TEST_TYPE'] == 'Raven')
matched_v_df.loc[rule, 'FIQ'] = matched_v_df.loc[rule,'PIQ']

# %%
# eliminar columna matched is camps d'IQ que ja no fan falta
matched_v_df.drop(['match','PIQ_TEST_TYPE','PIQ'], axis=1, inplace=True)
matched_v_df.reset_index(drop=True, inplace=True)
matched_v_df.head()
# Out:
#          SITE_ID SUB_ID  DX_GROUP  AGE_AT_SCAN   SEX    FIQ     subject  \
# 0  ABIDEII-BNI_1  29006         1          48.0    1  131.0  29006_anat
# 1  ABIDEII-BNI_1  29007         1          41.0    1  110.0  29007_anat
# 2  ABIDEII-BNI_1  29008         1          59.0    1  117.0  29008_anat
# 3  ABIDEII-BNI_1  29009         1          57.0    1  114.0  29009_anat
# 4  ABIDEII-BNI_1  29010         1          45.0    1  109.0  29010_anat
#
#    total intracranial  left cerebral white matter  left cerebral cortex  ...  \
# 0           1757710.2                   259873.33             268254.22  ...
# 1           1887349.1                   287961.53             298969.12  ...
# 2           1520280.5                   225936.42             230091.05  ...
# 3           1608100.8                   227813.52             238434.92  ...
# 4           1632847.5                   239377.64             254104.42  ...
#
#    right cerebellum white matter  right cerebellum cortex  right thalamus  \
# 0                      19157.395                51659.777        7459.366
# 1                      20529.336                58005.500        8901.793
# 2                      18873.488                51608.484        6077.783
# 3                      17285.945                51243.855        6651.206
# 4                      17225.818                52908.120        6557.378
#
#    right caudate  right putamen  right pallidum  right hippocampus  \
# 0       3932.502       6187.846        1874.996           4703.144
# 1       6474.621       7358.886        2035.508           4795.284
# 2       3628.519       5075.090        1480.917           3973.777
# 3       3745.923       6084.976        1708.314           4442.364
# 4       4574.962       5176.962        1761.316           4163.968
#
#    right amygdala  right accumbens area  right ventral DC
# 0        1945.425               722.759          4258.534
# 1        2219.866               823.072          5447.822
# 2        1891.503               656.890          3787.245
# 3        1948.577               683.984          3974.932
# 4        1840.350               760.056          4350.503
#
# [5 rows x 40 columns]

# %% [markdown]
# ## **PAS5: Guardar CSV**

# %%
matched_qc_df.to_csv(merged_qc_path)
matched_v_df.to_csv(merged_v_path)
